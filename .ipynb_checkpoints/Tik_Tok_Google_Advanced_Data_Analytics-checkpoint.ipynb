# %% [markdown]
# # **TikTok Project**
# **End-of-course project**

# %% [markdown]
# Welcome to the TikTok Project!
#
# You have just started as a data professional at TikTok.
#
# The team is still in the early stages of the project. You have received notice that TikTok's leadership team has approved the project proposal. To gain clear insights to prepare for a claims classification model, TikTok's provided data must be examined to begin the process of exploratory data analysis (EDA).

# %% [markdown]
# **Project plan**
#
# TikTok is working on the development of a predictive model that can determine whether a video contains a claim or offers an opinion. With a successful prediction model, TikTok can reduce the backlog of user reports and prioritize them more efficiently
# Project background
# In this activity, you will examine data provided and prepare it for analysis.
# <br/>
#
# **The purpose** of this project is to investigate and understand the data provided. This activity will:
#
# 1.   Acquaint you with the data
#
# 2.   Compile summary information about the data
#
# 3.   Begin the process of EDA and reveal insights contained in the data
#
# 4.   Prepare you for more in-depth EDA, hypothesis testing, and statistical analysis
#
# **The goal** is to construct a dataframe in Python, perform a cursory inspection of the provided dataset, and inform TikTok data team members of your findings.
# <br/>
# *This activity has three parts:*
#
# **Part 1:** Understand the situation
# * How can you best prepare to understand and organize the provided TikTok information?
#
# **Part 2:** Understand the data
#
# * Create a pandas dataframe for data learning and future exploratory data analysis (EDA) and statistical activities
#
# * Compile summary information about the data to inform next steps
#
# **Part 3:** Understand the variables
#
# * Use insights from your examination of the summary data to guide deeper investigation into variables
#
# <br/>
#
#
# TikTok’s data team is in the earliest stages of the claims classification project. The **following tasks** are needed before the team can begin the data analysis process:
#
#  *	A project proposal identifying the following:
#
#     * Organize project tasks into milestones
#
#     * Classify tasks using the PACE workflow
#
#     * Identify relevant stakeholders
#
# **Course 1 PACE Strategy Document** to plan your project while considering your audience members, teammates, key milestones, and overall project goal.
#
# **Create a project proposal for the data team.**
#
# For your first assignment, TikTok is asking for a project proposal that will create milestones for the tasks within the comment classification project. Remember to take into account your audience, team, project goal, and PACE stages of each task in planning your project deliverable.
#
# If you selected the TikTok scenario, you are working on the development of a predictive model that can be used to determine whether a video contains a claim or whether it offers an opinion.

# %% [markdown]
# # **TikTok users have the ability to report videos and comments that contain user claims.**
#
# These reports identify content that needs to be reviewed by moderators.
#
# This process generates a large number of user reports that are difficult to address quickly.
#
# Development of a predictive model that can determine whether a video contains a claim or offers an opinion.
#
# With a successful prediction model, TikTok can reduce the backlog of user reports and prioritize them more efficiently.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tik_tok_data = pd.read_csv("tiktok_dataset.csv")

# %%
tik_tok_df = pd.DataFrame(tik_tok_data)

# %%
tik_tok_df.columns.tolist()
# Out:
# ['#',
#  'claim_status',
#  'video_id',
#  'video_duration_sec',
#  'video_transcription_text',
#  'verified_status',
#  'author_ban_status',
#  'video_view_count',
#  'video_like_count',
#  'video_share_count',
#  'video_download_count',
#  'video_comment_count']

# %%
tik_tok_df.head(10)
# Out:
#     # claim_status    video_id  video_duration_sec  \
# 0   1        claim  7017666017                  59
# 1   2        claim  4014381136                  32
# 2   3        claim  9859838091                  31
# 3   4        claim  1866847991                  25
# 4   5        claim  7105231098                  19
# 5   6        claim  8972200955                  35
# 6   7        claim  4958886992                  16
# 7   8        claim  2270982263                  41
# 8   9        claim  5235769692                  50
# 9  10        claim  4660861094                  45
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
# 5  someone shared with me that gross domestic pro...    not verified
# 6  someone shared with me that elvis presley has ...    not verified
# 7  someone shared with me that the best selling s...    not verified
# 8  someone shared with me that about half of the ...    not verified
# 9  someone shared with me that it would take a 50...        verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# 2            active          902185.0           97690.0             2858.0
# 3            active          437506.0          239954.0            34812.0
# 4            active           56167.0           34987.0             4110.0
# 5      under review          336647.0          175546.0            62303.0
# 6            active          750345.0          486192.0           193911.0
# 7            active          547532.0            1072.0               50.0
# 8            active           24819.0           10160.0             1050.0
# 9            active          931587.0          171051.0            67739.0
#
#    video_download_count  video_comment_count
# 0                   1.0                  0.0
# 1                1161.0                684.0
# 2                 833.0                329.0
# 3                1234.0                584.0
# 4                 547.0                152.0
# 5                4293.0               1857.0
# 6                8616.0               5446.0
# 7                  22.0                 11.0
# 8                  53.0                 27.0
# 9                4104.0               2540.0

# %%
tik_tok_df.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# min            0.000000           0.000000              0.000000
# 25%          810.750000         115.000000              7.000000
# 50%         3403.500000         717.000000             46.000000
# 75%       125020.000000       18222.000000           1156.250000
# max       657830.000000      256130.000000          14994.000000
#
#        video_comment_count
# count         19084.000000
# mean            349.312146
# std             799.638865
# min               0.000000
# 25%               1.000000
# 50%               9.000000
# 75%             292.000000
# max            9599.000000

# %%
tik_tok_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
tik_tok_df['claim_status'].value_counts()
# Out:
# claim_status
# claim      9608
# opinion    9476
# Name: count, dtype: int64

# %%
claim = tik_tok_df[tik_tok_df['claim_status'] == 'claim']

# %%
opinion = tik_tok_df[tik_tok_df['claim_status'] == 'opinion']

# %%
claim_na = tik_tok_df[tik_tok_df['claim_status'].isna()]

# %% [markdown]
# # Claim VS Opinion

# %%
print("Number of videos categorized as claims:",len(claim))
print("Number of videos categorized as opinions:",len(opinion))
print("Total # of categorized videos:",len(opinion)+len(claim))
print("Number of videos without a claim status:", len(claim_na))
# Out:
# Number of videos categorized as claims: 9608
# Number of videos categorized as opinions: 9476
# Total # of categorized videos: 19084
# Number of videos without a claim status: 298

# %%
tik_tok_df = tik_tok_df.dropna()

# %%
tik_tok_df
# Out:
#            # claim_status    video_id  video_duration_sec  \
# 0          1        claim  7017666017                  59
# 1          2        claim  4014381136                  32
# 2          3        claim  9859838091                  31
# 3          4        claim  1866847991                  25
# 4          5        claim  7105231098                  19
# ...      ...          ...         ...                 ...
# 19079  19080      opinion  1492320297                  49
# 19080  19081      opinion  9841347807                  23
# 19081  19082      opinion  8024379946                  50
# 19082  19083      opinion  7425795014                   8
# 19083  19084      opinion  4094655375                  58
#
#                                 video_transcription_text verified_status  \
# 0      someone shared with me that drone deliveries a...    not verified
# 1      someone shared with me that there are more mic...    not verified
# 2      someone shared with me that american industria...    not verified
# 3      someone shared with me that the metro of st. p...    not verified
# 4      someone shared with me that the number of busi...    not verified
# ...                                                  ...             ...
# 19079  in our opinion the earth holds about 11 quinti...    not verified
# 19080  in our opinion the queens in ant colonies live...    not verified
# 19081  in our opinion the moon is moving away from th...    not verified
# 19082  in our opinion lightning strikes somewhere on ...    not verified
# 19083  in our opinion a pineapple plant can only prod...    not verified
#
#       author_ban_status  video_view_count  video_like_count  \
# 0          under review          343296.0           19425.0
# 1                active          140877.0           77355.0
# 2                active          902185.0           97690.0
# 3                active          437506.0          239954.0
# 4                active           56167.0           34987.0
# ...                 ...               ...               ...
# 19079            active            6067.0             423.0
# 19080            active            2973.0             820.0
# 19081            active             734.0             102.0
# 19082            active            3394.0             655.0
# 19083            active            5034.0             815.0
#
#        video_share_count  video_download_count  video_comment_count
# 0                  241.0                   1.0                  0.0
# 1                19034.0                1161.0                684.0
# 2                 2858.0                 833.0                329.0
# 3                34812.0                1234.0                584.0
# 4                 4110.0                 547.0                152.0
# ...                  ...                   ...                  ...
# 19079               81.0                   8.0                  2.0
# 19080               70.0                   3.0                  0.0
# 19081                7.0                   2.0                  1.0
# 19082              123.0                  11.0                  4.0
# 19083              281.0                  11.0                  1.0
#
# [19084 rows x 12 columns]

# %% [markdown]
# # Claim_status VS videos

# %%
claim_mean_med = claim.drop(columns=['#', 'video_id','video_duration_sec']).select_dtypes(include=[np.number]).agg(['mean', 'median']).round(2)

# %%
opinion_mean_med = opinion.drop(columns=['#', 'video_id','video_duration_sec']).select_dtypes(include=[np.number]).agg(['mean', 'median']).round(2)

# %%
claim_vs_opinion_perc = ((claim_mean_med-opinion_mean_med)/claim_mean_med*100).round(2).drop('median').rename({'mean':'mean percentage'})

# %%
claims_fin = pd.concat({'claim':claim_mean_med, 'opinion':opinion_mean_med, 'percentage claim/opinion':claim_vs_opinion_perc})
claims_fin
# Out:
#                                           video_view_count  video_like_count  \
# claim                    mean                    501029.45         166373.33
#                          median                  501555.00         123649.00
# opinion                  mean                      4956.43           1092.73
#                          median                    4953.00            823.00
# percentage claim/opinion mean percentage             99.01             99.34
#
#                                           video_share_count  \
# claim                    mean                      33026.42
#                          median                    17997.50
# opinion                  mean                        217.15
#                          median                      121.00
# percentage claim/opinion mean percentage              99.34
#
#                                           video_download_count  \
# claim                    mean                          2070.95
#                          median                        1139.50
# opinion                  mean                            13.68
#                          median                           7.00
# percentage claim/opinion mean percentage                 99.34
#
#                                           video_comment_count
# claim                    mean                          691.16
#                          median                        286.00
# opinion                  mean                            2.70
#                          median                          1.00
# percentage claim/opinion mean percentage                99.61

# %% [markdown]
# It can be easily said that who makes claiming drags more more attention from other people. The amount of videos viewed, liked, shared, downloaded and commented are a lot higher compare to videos where people give opinions. The difference from who gives a statement compared to who gives an opinion ranges from 99.01% to 99.61%. There are no variations in video duration.

# %% [markdown]
# # Active_ban VS videos

# %%
active_ban = tik_tok_df[tik_tok_df['author_ban_status'] == 'active']
banned_ban = tik_tok_df[tik_tok_df['author_ban_status'] == 'banned']
under_review_ban = tik_tok_df[tik_tok_df['author_ban_status'] == 'under review']

# %%
active_ban_mean_med = active_ban.drop(columns=['#', 'video_id','video_duration_sec']).select_dtypes(include=[np.number]).agg(['mean', 'median']).round(2)
banned_ban_mean_med = banned_ban.drop(columns=['#', 'video_id','video_duration_sec']).select_dtypes(include=[np.number]).agg(['mean', 'median']).round(2)
under_review_ban_mean_med = under_review_ban.drop(columns=['#', 'video_id','video_duration_sec']).select_dtypes(include=[np.number]).agg(['mean', 'median']).round(2)

# %%
author_ban_status = pd.concat({
    'active': active_ban_mean_med,
    'banned': banned_ban_mean_med,
    'under_review': under_review_ban_mean_med
})
author_ban_status
# Out:
#                      video_view_count  video_like_count  video_share_count  \
# active       mean           215927.04          71036.53           14111.47
#              median           8616.00           2222.00             437.00
# banned       mean           445845.44         153017.24           29998.94
#              median         448201.00         105573.00           14468.00
# under_review mean           392204.84         128718.05           25774.70
#              median         365245.50          71204.50            9444.00
#
#                      video_download_count  video_comment_count
# active       mean                  882.28               295.13
#              median                 28.00                 5.00
# banned       mean                 1886.30               614.96
#              median                892.00               209.00
# under_review mean                 1631.73               542.48
#              median                610.50               136.50

# %% [markdown]
# Who is banned has the most viewed, liked, shared, downloaded and commented videos, followed by under_review. These are people can are causing "troubles" in terms of report and likely to be reported.

# %%
print("Number of active people:", len(active_ban))
print("Number of actual ban:", len(banned_ban))
print("Number of people under review:", len(under_review_ban))
# Out:
# Number of active people: 15383
# Number of actual ban: 1635
# Number of people under review: 2066

# %%
verified = tik_tok_df[tik_tok_df['verified_status'] == 'verified']
verified_mean = verified.drop(columns=['#', 'video_id','video_duration_sec']).select_dtypes(include=[np.number]).agg(['mean', 'median']).round(2)

# %%
not_verified = tik_tok_df[tik_tok_df['verified_status'] == 'not verified']
not_verified_mean = not_verified.drop(columns=['#', 'video_id','video_duration_sec']).select_dtypes(include=[np.number]).agg(['mean', 'median']).round(2)

# %%
print("Number of verified users:", len(verified))
print("Number of not verified users:", len(not_verified))
print("Percentage difference verified/not_Verified:", round((len(verified) - len(not_verified)) / len(not_verified) * 100, 2))
# Out:
# Number of verified users: 1200
# Number of not verified users: 17884
# Percentage difference verified/not_Verified: -93.29

# %%
verified_perc = (((verified_mean-not_verified_mean)/verified_mean)*100).round(2).drop('median').rename({'mean':'mean percentage'})
verified_perc
# Out:
#                  video_view_count  video_like_count  video_share_count  \
# mean percentage           -190.54           -189.82            -164.22
#
#                  video_download_count  video_comment_count
# mean percentage               -205.96              -169.65

# %%
verified_and_not = pd.concat({'verified':verified_mean, 'not verified': not_verified_mean, 'percentage':verified_perc})
verified_and_not
# Out:
#                               video_view_count  video_like_count  \
# verified     mean                     91439.16          30337.63
#              median                    6023.50           1125.00
# not verified mean                    265663.79          87925.77
#              median                   46723.00           5156.00
# percentage   mean percentage           -190.54           -189.82
#
#                               video_share_count  video_download_count  \
# verified     mean                       6591.45                358.15
#              median                      178.50                 11.00
# not verified mean                      17415.89               1095.81
#              median                      879.00                 56.00
# percentage   mean percentage            -164.22               -205.96
#
#                               video_comment_count
# verified     mean                          134.88
#              median                          2.00
# not verified mean                          363.70
#              median                         12.00
# percentage   mean percentage              -169.65

# %%
tot = pd.concat({'claimings': claims_fin.drop('percentage claim/opinion'), 'author bans': author_ban_status, 'verifications': verified_and_not.drop('percentage')})
tot
# Out:
#                                    video_view_count  video_like_count  \
# claimings     claim        mean           501029.45         166373.33
#                            median         501555.00         123649.00
#               opinion      mean             4956.43           1092.73
#                            median           4953.00            823.00
# author bans   active       mean           215927.04          71036.53
#                            median           8616.00           2222.00
#               banned       mean           445845.44         153017.24
#                            median         448201.00         105573.00
#               under_review mean           392204.84         128718.05
#                            median         365245.50          71204.50
# verifications verified     mean            91439.16          30337.63
#                            median           6023.50           1125.00
#               not verified mean           265663.79          87925.77
#                            median          46723.00           5156.00
#
#                                    video_share_count  video_download_count  \
# claimings     claim        mean             33026.42               2070.95
#                            median           17997.50               1139.50
#               opinion      mean               217.15                 13.68
#                            median             121.00                  7.00
# author bans   active       mean             14111.47                882.28
#                            median             437.00                 28.00
#               banned       mean             29998.94               1886.30
#                            median           14468.00                892.00
#               under_review mean             25774.70               1631.73
#                            median            9444.00                610.50
# verifications verified     mean              6591.45                358.15
#                            median             178.50                 11.00
#               not verified mean             17415.89               1095.81
#                            median             879.00                 56.00
#
#                                    video_comment_count
# claimings     claim        mean                 691.16
#                            median               286.00
#               opinion      mean                   2.70
#                            median                 1.00
# author bans   active       mean                 295.13
#                            median                 5.00
#               banned       mean                 614.96
#                            median               209.00
#               under_review mean                 542.48
#                            median               136.50
# verifications verified     mean                 134.88
#                            median                 2.00
#               not verified mean                 363.70
#                            median                12.00

# %% [markdown]
# # Final
# The **core findings** are that **claim** videos get disproportionately more interactions, channels under **active ban** are surprisingly the most viewed,liked,shared,downloaded, and that **unverified users** (especially those making claims) **dominate interactions**.
#
# The number of videos containing **claims and opinions** are almost in equal numbers.
# The **distribution** is evidently **right skewed** from the data. Plots would help understand more the situation.
#
# These findings hint at:
#
# * A “controversy‐drives‐engagement” effect: **claim-heavy content gets amplified.**
#
# * A paradox where  hit the **most popular creators** receive bans most often from TikTok’s moderation flags
#
# * **Verification status** as a measure for content type and engagement strategy.

# %% [markdown]
# #  Data visualisation

# %%
claim_counts = tik_tok_df['claim_status'].value_counts()
plt.figure()
plt.bar(claim_counts.index, claim_counts.values, edgecolor='k')
plt.title("Video Count by Claim Status")
plt.xlabel("Claim Status")
plt.ylabel("Number of Videos")
for idx, val in enumerate(claim_counts.values):
    plt.text(idx, val + max(claim_counts.values)*0.01, f"{val}", ha='center')
plt.tight_layout()
plt.show()

# %%
metrics = ['video_view_count', 'video_like_count', 'video_share_count', 
           'video_download_count', 'video_comment_count']
avg_engagement = tik_tok_df.groupby('author_ban_status')[metrics].mean()
bottom = [0] * len(avg_engagement)

plt.figure()
for metric in metrics:
    plt.bar(avg_engagement.index, avg_engagement[metric], bottom=bottom, edgecolor='k')
    bottom = bottom + avg_engagement[metric].values
plt.title("Average Engagement by Ban Status")
plt.xlabel("Author Ban Status")
plt.ylabel("Average Count")
plt.legend(metrics, title="Metrics")
plt.tight_layout()
plt.show()

# %%
plt.figure()
tik_tok_df.boxplot(column='video_like_count', by='verified_status')
plt.title("Likes Distribution by Verification Status")
plt.suptitle("")
plt.xlabel("Verified Status")
plt.ylabel("Video Like Count")
plt.tight_layout()
plt.show()

# %%
# Visualizing the relationship between claim status, author ban status, and engagement
plt.figure(figsize=(10,6))
sns.boxplot(
	data=tik_tok_df,
	x='claim_status',
	y='video_view_count',
	hue='author_ban_status',
	showfliers=False
)
plt.title("Video Views by Claim Status and Author Ban Status")
plt.xlabel("Claim Status")
plt.ylabel("Video View Count")
plt.legend(title="Author Ban Status")
plt.tight_layout()
plt.show()

# %%
# 2. Distribution of video durations by claim status
plt.figure()
sns.boxplot(data=tik_tok_df, x='claim_status', y='video_duration_sec')
plt.title("Video Duration by Claim Status")
plt.xlabel("Claim Status")
plt.ylabel("Video Duration (sec)")
plt.tight_layout()
plt.show()

# %%
# 3. Engagement metrics by verification and ban status
engagement_metrics = ['video_view_count', 'video_like_count', 'video_share_count', 'video_download_count', 'video_comment_count']
grouped = tik_tok_df.groupby(['verified_status', 'author_ban_status'])[engagement_metrics].mean().unstack()
grouped.plot(kind='bar', figsize=(12, 6))
plt.title("Average Engagement by Verification and Ban Status")
plt.ylabel("Average Count")
plt.tight_layout()
plt.show()

# %%
# 4. Proportion of claim vs opinion within each ban status
claim_opinion_by_ban = tik_tok_df.groupby(['author_ban_status', 'claim_status']).size().unstack().fillna(0)
claim_opinion_by_ban.plot(kind='bar', stacked=True)
plt.title("Claim vs Opinion Distribution by Author Ban Status")
plt.xlabel("Author Ban Status")
plt.ylabel("Number of Videos")
plt.tight_layout()
plt.show()

# %%
plt.style.use('default')
sns.set_palette("husl")

# 1. ENGAGEMENT COMPARISON: LOG SCALE (to handle the massive differences)
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Engagement Metrics: Claims vs Opinions (Log Scale)', fontsize=16, fontweight='bold')

metrics = ['video_view_count', 'video_like_count', 'video_share_count', 
           'video_download_count', 'video_comment_count']

for i, metric in enumerate(metrics):
    ax = axes[i//3, i%3]
    
    claim_data = claim[metric].dropna()
    opinion_data = opinion[metric].dropna()
    
    # Box plot with log scale
    data_to_plot = [claim_data, opinion_data]
    box = ax.boxplot(data_to_plot, tick_labels=['Claims', 'Opinions'], patch_artist=True)
    
    # Color the boxes
    box['boxes'][0].set_facecolor('#ff6b6b')
    box['boxes'][1].set_facecolor('#74b9ff')
    
    ax.set_yscale('log')
    ax.set_title(metric.replace('_', ' ').title())
    ax.grid(True, alpha=0.3)

# Remove empty subplot
axes[1, 2].remove()
plt.tight_layout()
plt.show()

# %%
# 2. DISTRIBUTION PLOTS: Show the right-skewed nature
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Distribution Analysis: Right-Skewed Engagement Patterns', fontsize=16)

# Video views distribution
axes[0,0].hist(tik_tok_df['video_view_count'], bins=50, alpha=0.7, color='skyblue', edgecolor='black')
axes[0,0].set_title('Video Views Distribution')
axes[0,0].set_xlabel('Views')
axes[0,0].set_ylabel('Frequency')
axes[0,0].set_yscale('log')

# Likes distribution by claim status
claim_likes = claim['video_like_count'].dropna()
opinion_likes = opinion['video_like_count'].dropna()

axes[0,1].hist(claim_likes, bins=50, alpha=0.7, label='Claims', color='#ff6b6b')
axes[0,1].hist(opinion_likes, bins=50, alpha=0.7, label='Opinions', color='#74b9ff')
axes[0,1].set_title('Likes Distribution by Content Type')
axes[0,1].set_xlabel('Likes')
axes[0,1].set_ylabel('Frequency')
axes[0,1].legend()
axes[0,1].set_yscale('log')

# Ban status vs engagement scatter
ban_engagement = tik_tok_df.groupby('author_ban_status')[['video_view_count', 'video_like_count']].mean()
axes[1,0].scatter(ban_engagement['video_view_count'], ban_engagement['video_like_count'], 
                 s=200, alpha=0.7, c=['#feca57', '#ff6b6b', '#48dbfb'])
for i, status in enumerate(ban_engagement.index):
    axes[1,0].annotate(status, (ban_engagement.iloc[i,0], ban_engagement.iloc[i,1]), 
                      xytext=(5, 5), textcoords='offset points')
axes[1,0].set_title('Ban Status vs Average Engagement')
axes[1,0].set_xlabel('Average Views')
axes[1,0].set_ylabel('Average Likes')

# Verification status comparison
verify_stats = tik_tok_df.groupby('verified_status')[['video_view_count', 'video_like_count', 
                                                     'video_share_count', 'video_comment_count']].mean()
x = np.arange(len(verify_stats.columns))
width = 0.35

verified_values = verify_stats.loc['verified'].values
not_verified_values = verify_stats.loc['not verified'].values

axes[1,1].bar(x - width/2, verified_values, width, label='Verified', alpha=0.8, color='#00cec9')
axes[1,1].bar(x + width/2, not_verified_values, width, label='Not Verified', alpha=0.8, color='#fd79a8')
axes[1,1].set_title('Verified vs Not Verified Engagement')
axes[1,1].set_xticks(x)
axes[1,1].set_xticklabels(['Views', 'Likes', 'Shares', 'Comments'], rotation=45)
axes[1,1].legend()
axes[1,1].set_yscale('log')

plt.tight_layout()
plt.show()

# %%
# 4. CLAIMS vs OPINIONS: Dramatic Difference Visualization
fig, ax = plt.subplots(figsize=(12, 8))

categories = ['Views', 'Likes', 'Shares', 'Downloads', 'Comments']
claim_means = [claim['video_view_count'].mean(), claim['video_like_count'].mean(), 
               claim['video_share_count'].mean(), claim['video_download_count'].mean(), 
               claim['video_comment_count'].mean()]
opinion_means = [opinion['video_view_count'].mean(), opinion['video_like_count'].mean(), 
                opinion['video_share_count'].mean(), opinion['video_download_count'].mean(), 
                opinion['video_comment_count'].mean()]

# Calculate percentage differences
differences = [(c-o)/o*100 for c, o in zip(claim_means, opinion_means)]

x = np.arange(len(categories))
width = 0.35

bars1 = ax.bar(x - width/2, claim_means, width, label='Claims', color='#ff6b6b', alpha=0.8)
bars2 = ax.bar(x + width/2, opinion_means, width, label='Opinions', color='#74b9ff', alpha=0.8)

# Add percentage labels
for i, diff in enumerate(differences):
    ax.text(i, max(claim_means[i], opinion_means[i]) * 1.1, f'+{diff:.0f}%', 
            ha='center', va='bottom', fontweight='bold', fontsize=12, color='red')

ax.set_yscale('log')
ax.set_xlabel('Engagement Metrics')
ax.set_ylabel('Average Count (Log Scale)')
ax.set_title('The Claim Advantage: 10,000%+ Higher Engagement', fontsize=16, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# 5. BAN STATUS TIMELINE/FUNNEL ANALYSIS
ban_counts = tik_tok_df['author_ban_status'].value_counts()
ban_engagement = tik_tok_df.groupby('author_ban_status')['video_view_count'].mean()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Count plot
colors = ['#48dbfb', '#feca57', '#ff6b6b']
bars1 = ax1.bar(ban_counts.index, ban_counts.values, color=colors, alpha=0.8)
ax1.set_title('Distribution by Ban Status', fontsize=14, fontweight='bold')
ax1.set_ylabel('Number of Users')
for bar, count in zip(bars1, ban_counts.values):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height + count*0.01,
             f'{count:,}', ha='center', va='bottom', fontweight='bold')
# Engagement by ban status
bars2 = ax2.bar(ban_engagement.index, ban_engagement.values, color=colors, alpha=0.8)
ax2.set_title('Average Views by Ban Status', fontsize=14, fontweight='bold')
ax2.set_ylabel('Average Views')
for bar, views in zip(bars2, ban_engagement.values):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + views*0.01,
             f'{views:,.0f}', ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# 2. Countplot: Author ban status by verification status
plt.figure(figsize=(7,5))
sns.countplot(data=tik_tok_df, x='author_ban_status', hue='verified_status')
plt.title("Author Ban Status by Verification Status")
plt.xlabel("Author Ban Status")
plt.ylabel("Number of Videos")
plt.tight_layout()
plt.show()

# %%
# 1. Pie chart: Distribution of claim vs opinion videos
plt.figure()
claim_opinion_counts = tik_tok_df['claim_status'].value_counts()
plt.pie(claim_opinion_counts, labels=claim_opinion_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title("Distribution of Claim vs Opinion Videos")
plt.axis('equal')
plt.show()

# %%
# 3. Violin plot: Engagement (likes) by claim status and verification
plt.figure(figsize=(8,5))
sns.violinplot(data=tik_tok_df, x='claim_status', y='video_like_count', hue='verified_status', split=True)
plt.title("Likes Distribution by Claim Status and Verification")
plt.xlabel("Claim Status")
plt.ylabel("Video Like Count")
plt.tight_layout()
plt.show()

# %%
# 5. Boxplot: Comment count by author ban status
plt.figure(figsize=(7,5))
sns.boxplot(data=tik_tok_df, x='author_ban_status', y='video_comment_count')
plt.title("Comment Count by Author Ban Status")
plt.xlabel("Author Ban Status")
plt.ylabel("Video Comment Count")
plt.tight_layout()
plt.show()

# %%
# 3. CORRELATION HEATMAP: Show relationships between metrics
correlation_data = tik_tok_df[['video_view_count', 'video_like_count', 'video_share_count', 
                              'video_download_count', 'video_comment_count', 'video_duration_sec']].corr()

plt.figure(figsize=(10, 8))
mask = np.triu(np.ones_like(correlation_data, dtype=bool))
sns.heatmap(correlation_data, mask=mask, annot=True, cmap='RdYlBu_r', center=0,
            square=True, linewidths=0.5, cbar_kws={"shrink": 0.8})
plt.title('Engagement Metrics Correlation Matrix', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# 1. Correlation heatmap for numeric features
plt.figure(figsize=(10, 8))
sns.heatmap(tik_tok_df.select_dtypes(include=[np.number]).corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Numeric Features")
plt.tight_layout()
plt.show()

# %%
# Heatmap: Average engagement metrics by claim status and verification
engagement_metrics = ['video_view_count', 'video_like_count', 'video_share_count', 'video_download_count', 'video_comment_count']
pivot = tik_tok_df.groupby(['claim_status', 'verified_status'])[engagement_metrics].mean().round(1)
plt.figure(figsize=(10,6))
sns.heatmap(pivot, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title("Average Engagement by Claim Status and Verification Status")
plt.ylabel("Claim Status / Verified Status")
plt.tight_layout()
plt.show()
